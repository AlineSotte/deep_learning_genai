# %% [markdown]
# ### 1. **O que é RAG (Retrieval-Augmented Generation)?**
#
# - a) Uma técnica para ajustar hiperparâmetros.
# - b) Uma abordagem para incorporar informações de recuperação em modelos generativos.
# - c) Um algoritmo de clustering.
# - d) Um método de compressão de dados.

# %% [markdown]
# Sua resposta: B

# %% [markdown]
# ### 2. **Qual é a principal função de um agente em IA?**
#
# - a) Melhorar a qualidade da imagem.
# - b) Minerar dados.
# - c) Realizar tarefas específicas de forma autônoma.
# - d) Otimizar o código.

# %% [markdown]
# Sua resposta: C

# %% [markdown]
# ### 3. **O que é o Langchain?**
#
# - a) Uma biblioteca para encadear modelos de linguagem.
# - b) Uma plataforma de análise de imagens.
# - c) Um algoritmo de classificação.
# - d) Uma ferramenta de visualização de dados.

# %% [markdown]
# Sua resposta: A

# %% [markdown]
# ### 4. **Qual é a principal característica dos Agentes em IA?**
#
# - a) Processamento de linguagem natural.
# - b) Tomada de decisão autônoma.
# - c) Renderização gráfica.
# - d) Otimização de hiperparâmetros.

# %% [markdown]
# Sua resposta: B

# %% [markdown]
# ### 5. **Qual linguagem de programação é frequentemente usada com Langchain?**
#
# - a) Java
# - b) C++
# - c) Julia
# - d) Python

# %% [markdown]
# Sua resposta: D

# %% [markdown]
# ### 6. **Qual é uma característica-chave da abordagem RAG?**
#
# - a) Uso de redes convolucionais.
# - b) Aplicação em análise de sentimento.
# - c) Integração de recuperação de informações com geração de texto.
# - d) Compressão de dados.

# %% [markdown]
# Sua resposta: C

# %% [markdown]
# ### 7. **Qual é a função de um agente de LLM?**
#
# - a) Analisar dados meteorológicos.
# - b) Renderizar imagens 3D.
# - c) Melhorar a precisão de previsões econômicas.
# - d) Automatizar tarefas específicas.

# %% [markdown]
# Sua resposta: D

# %% [markdown]
# ### 8. **O que é um exemplo de aplicação mais comum de agentes em IA?**
#
# - a) Tradução automática.
# - b) Renderização de gráficos.
# - c) Simulação de processos químicos.
# - d) Otimização de algoritmos de clustering.

# %% [markdown]
# Sua resposta: A

# %% [markdown]
# ### 9. **O que é um vector store em IA?**
#
# - a) Uma técnica de compressão de imagens.
# - b) Uma ferramenta de visualização de dados.
# - c) Um algoritmo de classificação de texto.
# - d) Um banco de dados especializado para armazenar e recuperar vetores.

# %% [markdown]
# Sua resposta: D

# %% [markdown]
# ### 10. **Qual é a principal função de um chatbot?**
#
# - a) Analisar dados financeiros.
# - b) Manter conversações automatizadas com usuários.
# - c) Renderizar gráficos em 3D.
# - d) Realizar tarefas de clustering.

# %% [markdown]
# Sua resposta: B
