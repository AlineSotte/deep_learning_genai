# %% [markdown]
# ### 1. **O que é uma rede neural?**
#    - A) Um algoritmo de aprendizado supervisionado
#    - B) Um modelo matemático inspirado no cérebro humano
#    - C) Um tipo de banco de dados
#    - D) Um sistema operacional

# %% [markdown]
# Sua resposta: ____

# %% [markdown]
# ### 2. **Qual é a função da camada de ativação em uma rede neural?**
#    - A) Armazenar dados
#    - B) Normalizar os dados
#    - C) Reduzir o overfitting
#    - D) Introduzir não-linearidade no modelo

# %% [markdown]
# Sua resposta: ____

# %% [markdown]
# ### 3. **O que é retropropagação (backpropagation)?**
#    - A) Um método de inicialização de pesos
#    - B) Um algoritmo de otimização
#    - C) Um processo de ajuste de pesos baseado no erro
#    - D) Uma técnica de regularização

# %% [markdown]
# Sua resposta: ____

# %% [markdown]
# ### 4. **Qual das seguintes é uma função de ativação comumente usada?**
#    - A) Sigmoid
#    - B) Linear
#    - C) Quadrática
#    - D) Exponencial

# %% [markdown]
# Sua resposta: ____

# %% [markdown]
# ### 5. **O que é overfitting em redes neurais?**
#    - A) Quando o modelo se ajusta muito bem aos dados de treinamento, mas falha em generalizar para novos dados
#    - B) Quando o modelo não se ajusta bem aos dados de treinamento
#    - C) Quando o modelo tem muitos dados de entrada
#    - D) Quando o modelo usa uma função de ativação inadequada

# %% [markdown]
# Sua resposta: ____

# %% [markdown]
# ### 6. **Qual é o papel dos pesos em uma rede neural?**
#    - A) Armazenar os dados de entrada
#    - B) Ajustar a saída da rede
#    - C) Conectar neurônios entre camadas
#    - D) Normalizar os dados de entrada

# %% [markdown]
# Sua resposta: ____

# %% [markdown]
# ### 7. **Como as redes neurais convolucionais (CNNs) usualmente são utilizadas?**
#    - A) Em sistemas de recomendação
#    - B) Para análise de séries temporais
#    - C) Para processamento de linguagem natural
#    - D) Em tarefas de visão computacional

# %% [markdown]
# Sua resposta: ____

# %% [markdown]
# ### 8. **O que é uma rede neural profunda (deep neural network)?**
#    - A) Uma rede com uma única camada oculta
#    - B) Uma rede com múltiplas camadas ocultas
#    - C) Uma rede com apenas uma camada de entrada e uma de saída
#    - D) Uma rede que não usa funções de ativação

# %% [markdown]
# Sua resposta: ____

# %% [markdown]
# ### 9. **Qual é a importância da regularização em redes neurais?**
#    - A) Aumentar a complexidade do modelo
#    - B) Reduzir o tempo de treinamento
#    - C) Prevenir overfitting
#    - D) Melhorar a precisão dos dados de entrada

# %% [markdown]
# Sua resposta: ____

# %% [markdown]
# ### 10. **Como as redes neurais podem ser aplicadas em NLP?**
#     - A) Para reconhecimento de padrões em imagens
#     - B) Para análise de sentimentos e tradução automática
#     - C) Para prever séries temporais financeiras
#     - D) Para controle de robôs

# %% [markdown]
# Sua resposta: ____

# %% [markdown]
# ### 11. **Qual é a principal vantagem de usar a API Sequencial do Keras?**
#    - A) Permite a criação de modelos com múltiplas entradas e saídas
#    - B) Facilita a criação de camadas personalizadas
#    - C) Oferece suporte a topologias não lineares
#    - D) É ideal para criar modelos com uma única entrada e saída em uma pilha linear de camadas

# %% [markdown]
# Sua resposta: ____

# %% [markdown]
# ### 12. **O que a API Funcional (classe `Model`) do Keras permite que você faça?**
#    - A) Construir modelos com topologias não lineares, camadas compartilhadas e múltiplas entradas ou saídas
#    - B) Criar modelos apenas com uma única camada
#    - C) Treinar modelos sem a necessidade de dados de entrada
#    - D) Utilizar apenas funções de ativação lineares

# %% [markdown]
# Sua resposta: ____

# %% [markdown]
# ### 13. **Qual das seguintes opções é uma característica do Keras?**
#    - A) Interface complexa e difícil de usar
#    - B) Suporte limitado a frameworks de aprendizado profundo
#    - C) Alta compatibilidade com TensorFlow, JAX e Pytorch
#    - D) Incompatibilidade com GPUs

# %% [markdown]
# Sua resposta: ____

# %% [markdown]
# ### 14. **Como o Keras facilita a experimentação rápida com redes neurais?**
#    - A) Fornecendo uma interface de baixo nível para manipulação de dados
#    - B) Oferecendo abstrações de alto nível que permitem a rápida prototipagem e teste de diferentes arquiteturas de redes neurais
#    - C) Limitando o número de camadas que podem ser usadas
#    - D) Exigindo conhecimento avançado de programação para uso

# %% [markdown]
# Sua resposta: ____

# %% [markdown]
# ### 15. **Qual é a função da camada `Dense` no Keras?**
#    - A) Normalizar os dados de entrada
#    - B) Aplicar regularização L2 automaticamente
#    - C) Reduzir o número de parâmetros no modelo
#    - D) Conectar cada neurônio de uma camada à próxima camada

# %% [markdown]
# Sua resposta: ____
